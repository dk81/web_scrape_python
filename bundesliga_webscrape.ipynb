# %% [markdown]
# ## Bundesliga German Football Table Web Scraping

# %%
# Import libraries

import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.bundesliga.com/en/bundesliga/table"

response = requests.get(url)

response.status_code
# Out:
# 200

# %% [markdown]
# ## Get Soup

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# From the soup object, the table in the Bundesliga page can be found in the table tag. The rows can be found with the `tr` tags when you use Inspect from right clicking a page.

# %%
results = soup.find('table', {'class': 'table'}).find_all('tr')

# %%
# Remove first row (header):

results = results[1:]

# %%
# Number of teams should be 18
len(results)
# Out:
# 18

# %% [markdown]
# ## Get Team Name

# %% [markdown]
# The team name can found from the `td` tag with the class name as `team` then the `a` tag and then the `span` tag with the class of `d-none d-lg-inline`.

# %%
results[0].find('td', {'class': 'team'}).find('span', {'class': 'd-none d-lg-inline'}).get_text()
# Out:
# 'FC Bayern München'

# %%
results[17].find('td', {'class': 'team'}).find('span', {'class': 'd-none d-lg-inline'}).get_text()
# Out:
# 'SpVgg Greuther Fürth'

# %% [markdown]
# ## Number Of Matches
#
# The class of interest is `matches` which is from the `td` tags.

# %%
results[0].find('td', {'class': 'matches'}).get_text()
# Out:
# '22'

# %% [markdown]
# ## Points

# %%
results[0].find('td', {'class': 'pts'}).get_text()
# Out:
# '52'

# %% [markdown]
# ## Wins, Draws, Losses

# %%
# Wins:

results[0].find('td', {'class': 'd-none d-lg-table-cell wins'}).get_text()
# Out:
# '17'

# %%
# Draws:

results[0].find('td', {'class': 'd-none d-lg-table-cell draws'}).get_text()
# Out:
# '1'

# %%
# Losses

results[0].find('td', {'class': 'd-none d-lg-table-cell looses'}).get_text()
# Out:
# '4'

# %% [markdown]
# ## Goals

# %%
results[0].find('td', {'class': 'd-none d-md-table-cell goals'}).get_text()
# Out:
# '70:25'

# %% [markdown]
# ## Goal Difference

# %%
# Remove plus sign cases

results[0].find('td', {'class': 'difference'}).get_text().replace("+", "")
# Out:
# '45'

# %%
results[17].find('td', {'class': 'difference'}).get_text().replace("+", "")
# Out:
# '-37'

# %% [markdown]
# ## Creating Table

# %%
# Webscrape the table, I use list comprhension instead of for loop append method:

teams = [result.find('td', {'class': 'team'}).find('span', {'class': 'd-none d-lg-inline'}).get_text() 
         for result in results]
    
matches = [result.find('td', {'class': 'matches'}).get_text() for result in results]

points = [result.find('td', {'class': 'pts'}).get_text() for result in results]

wins = [result.find('td', {'class': 'd-none d-lg-table-cell wins'}).get_text() for result in results]

draws = [result.find('td', {'class': 'd-none d-lg-table-cell draws'}).get_text() for result in results]

losses = [result.find('td', {'class': 'd-none d-lg-table-cell looses'}).get_text() for result in results]

goals = [result.find('td', {'class': 'd-none d-md-table-cell goals'}).get_text() for result in results]

goal_diff = [result.find('td', {'class': 'difference'}).get_text().replace("+", "") for result in results]

# %%
## Make pandas Dataframe:

bundesliga_df = pd.DataFrame({'Rank': range(1, 19), 'Team': teams, 'Matches': matches,
                              'Points': points, 'Wins': wins, 'Draws': draws,
                              'Losses': losses, 'Goals': goals, 'Goal Difference': goal_diff})

# %%
bundesliga_df
# Out:
#     Rank                  Team Matches Points Wins Draws Losses  Goals  \
# 0      1     FC Bayern München      22     52   17     1      4  70:25
# 1      2     Borussia Dortmund      22     46   15     1      6  57:36
# 2      3   Bayer 04 Leverkusen      22     41   12     5      5  58:36
# 3      4            RB Leipzig      22     34   10     4      8  43:27
# 4      5        TSG Hoffenheim      22     34   10     4      8  43:34
# 5      6           SC Freiburg      22     34    9     7      6  34:25
# 6      7    1. FC Union Berlin      22     34    9     7      6  29:30
# 7      8            1. FC Köln      22     32    8     8      6  34:37
# 8      9       1. FSV Mainz 05      22     31    9     4      9  31:24
# 9     10   Eintracht Frankfurt      22     31    8     7      7  33:34
# 10    11       VfL Bochum 1848      22     28    8     4     10  24:32
# 11    12         VfL Wolfsburg      22     27    8     3     11  23:33
# 12    13   Borussia M'gladbach      22     26    7     5     10  30:40
# 13    14         Hertha Berlin      22     23    6     5     11  24:45
# 14    15     Arminia Bielefeld      22     22    4    10      8  21:29
# 15    16           FC Augsburg      22     22    5     7     10  24:38
# 16    17         VfB Stuttgart      22     18    4     6     12  26:42
# 17    18  SpVgg Greuther Fürth      22     13    3     4     15  20:57
#
#    Goal Difference
# 0               45
# 1               21
# 2               22
# 3               16
# 4                9
# 5                9
# 6               -1
# 7               -3
# 8                7
# 9               -1
# 10              -8
# 11             -10
# 12             -10
# 13             -21
# 14              -8
# 15             -14
# 16             -16
# 17             -37

# %%
## Split Goals Into Goals For & Goals Against:

bundesliga_df[['Goals For','Goals Against']] = bundesliga_df['Goals'].str.split(":",expand=True,)

# %%
bundesliga_df
# Out:
#     Rank                  Team Matches Points Wins Draws Losses  Goals  \
# 0      1     FC Bayern München      22     52   17     1      4  70:25
# 1      2     Borussia Dortmund      22     46   15     1      6  57:36
# 2      3   Bayer 04 Leverkusen      22     41   12     5      5  58:36
# 3      4            RB Leipzig      22     34   10     4      8  43:27
# 4      5        TSG Hoffenheim      22     34   10     4      8  43:34
# 5      6           SC Freiburg      22     34    9     7      6  34:25
# 6      7    1. FC Union Berlin      22     34    9     7      6  29:30
# 7      8            1. FC Köln      22     32    8     8      6  34:37
# 8      9       1. FSV Mainz 05      22     31    9     4      9  31:24
# 9     10   Eintracht Frankfurt      22     31    8     7      7  33:34
# 10    11       VfL Bochum 1848      22     28    8     4     10  24:32
# 11    12         VfL Wolfsburg      22     27    8     3     11  23:33
# 12    13   Borussia M'gladbach      22     26    7     5     10  30:40
# 13    14         Hertha Berlin      22     23    6     5     11  24:45
# 14    15     Arminia Bielefeld      22     22    4    10      8  21:29
# 15    16           FC Augsburg      22     22    5     7     10  24:38
# 16    17         VfB Stuttgart      22     18    4     6     12  26:42
# 17    18  SpVgg Greuther Fürth      22     13    3     4     15  20:57
#
#    Goal Difference Goals For Goals Against
# 0               45        70            25
# 1               21        57            36
# 2               22        58            36
# 3               16        43            27
# 4                9        43            34
# 5                9        34            25
# 6               -1        29            30
# 7               -3        34            37
# 8                7        31            24
# 9               -1        33            34
# 10              -8        24            32
# 11             -10        23            33
# 12             -10        30            40
# 13             -21        24            45
# 14              -8        21            29
# 15             -14        24            38
# 16             -16        26            42
# 17             -37        20            57

# %%
# Drop Goals column and rearrange columns:

bundesliga_df.drop('Goals', axis = 1, inplace = True)

bundesliga_df
# Out:
#     Rank                  Team Matches Points Wins Draws Losses  \
# 0      1     FC Bayern München      22     52   17     1      4
# 1      2     Borussia Dortmund      22     46   15     1      6
# 2      3   Bayer 04 Leverkusen      22     41   12     5      5
# 3      4            RB Leipzig      22     34   10     4      8
# 4      5        TSG Hoffenheim      22     34   10     4      8
# 5      6           SC Freiburg      22     34    9     7      6
# 6      7    1. FC Union Berlin      22     34    9     7      6
# 7      8            1. FC Köln      22     32    8     8      6
# 8      9       1. FSV Mainz 05      22     31    9     4      9
# 9     10   Eintracht Frankfurt      22     31    8     7      7
# 10    11       VfL Bochum 1848      22     28    8     4     10
# 11    12         VfL Wolfsburg      22     27    8     3     11
# 12    13   Borussia M'gladbach      22     26    7     5     10
# 13    14         Hertha Berlin      22     23    6     5     11
# 14    15     Arminia Bielefeld      22     22    4    10      8
# 15    16           FC Augsburg      22     22    5     7     10
# 16    17         VfB Stuttgart      22     18    4     6     12
# 17    18  SpVgg Greuther Fürth      22     13    3     4     15
#
#    Goal Difference Goals For Goals Against
# 0               45        70            25
# 1               21        57            36
# 2               22        58            36
# 3               16        43            27
# 4                9        43            34
# 5                9        34            25
# 6               -1        29            30
# 7               -3        34            37
# 8                7        31            24
# 9               -1        33            34
# 10              -8        24            32
# 11             -10        23            33
# 12             -10        30            40
# 13             -21        24            45
# 14              -8        21            29
# 15             -14        24            38
# 16             -16        26            42
# 17             -37        20            57

# %%
bundesliga_df = bundesliga_df.reindex(columns=['Rank', 'Team', 'Matches', 'Points',
                                               'Wins', 'Draws', 'Losses', 'Goals For',
                                               'Goals Against', 'Goal Difference'])

# %%
bundesliga_df
# Out:
#     Rank                  Team Matches Points Wins Draws Losses Goals For  \
# 0      1     FC Bayern München      22     52   17     1      4        70
# 1      2     Borussia Dortmund      22     46   15     1      6        57
# 2      3   Bayer 04 Leverkusen      22     41   12     5      5        58
# 3      4            RB Leipzig      22     34   10     4      8        43
# 4      5        TSG Hoffenheim      22     34   10     4      8        43
# 5      6           SC Freiburg      22     34    9     7      6        34
# 6      7    1. FC Union Berlin      22     34    9     7      6        29
# 7      8            1. FC Köln      22     32    8     8      6        34
# 8      9       1. FSV Mainz 05      22     31    9     4      9        31
# 9     10   Eintracht Frankfurt      22     31    8     7      7        33
# 10    11       VfL Bochum 1848      22     28    8     4     10        24
# 11    12         VfL Wolfsburg      22     27    8     3     11        23
# 12    13   Borussia M'gladbach      22     26    7     5     10        30
# 13    14         Hertha Berlin      22     23    6     5     11        24
# 14    15     Arminia Bielefeld      22     22    4    10      8        21
# 15    16           FC Augsburg      22     22    5     7     10        24
# 16    17         VfB Stuttgart      22     18    4     6     12        26
# 17    18  SpVgg Greuther Fürth      22     13    3     4     15        20
#
#    Goals Against Goal Difference
# 0             25              45
# 1             36              21
# 2             36              22
# 3             27              16
# 4             34               9
# 5             25               9
# 6             30              -1
# 7             37              -3
# 8             24               7
# 9             34              -1
# 10            32              -8
# 11            33             -10
# 12            40             -10
# 13            45             -21
# 14            29              -8
# 15            38             -14
# 16            42             -16
# 17            57             -37

# %% [markdown]
# ## All In One Function
#
# Putting it all together in one function. I did not include saving the table into a .csv or Excel file. All the values are strings. The user would have to convert them into numeric if they want to.

# %%
def bundesliga_scrape():
    
    url = "https://www.bundesliga.com/en/bundesliga/table"

    response = requests.get(url)
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    results = soup.find('table', {'class': 'table'}).find_all('tr')
    
    # Remove first row:

    results = results[1:]
    
    # Webscrape the table, I use list comprhension instead of for loop append method:

    teams = [result.find('td', {'class': 'team'}).find('span', {'class': 'd-none d-lg-inline'}).get_text() 
             for result in results]  
    matches = [result.find('td', {'class': 'matches'}).get_text() for result in results]
    points = [result.find('td', {'class': 'pts'}).get_text() for result in results]

    wins = [result.find('td', {'class': 'd-none d-lg-table-cell wins'}).get_text() for result in results]
    draws = [result.find('td', {'class': 'd-none d-lg-table-cell draws'}).get_text() for result in results]
    losses = [result.find('td', {'class': 'd-none d-lg-table-cell looses'}).get_text() for result in results]

    goals = [result.find('td', {'class': 'd-none d-md-table-cell goals'}).get_text() for result in results]
    goal_diff = [result.find('td', {'class': 'difference'}).get_text().replace("+", "") for result in results]
    
    ## Make pandas Dataframe:

    df = pd.DataFrame({'Rank': range(1, 19), 'Team': teams, 'Matches': matches,
                              'Points': points, 'Wins': wins, 'Draws': draws,
                              'Losses': losses, 'Goals': goals, 'Goal Difference': goal_diff})
    
    # Split Goals Into Goals For & Goals Against:
    df[['Goals For','Goals Against']] = df['Goals'].str.split(":",expand=True,)
    
    # Drop Goals column
    df.drop('Goals', axis = 1, inplace = True)
    
    # Rearrange columns
    df = df.reindex(columns=['Rank', 'Team', 'Matches', 'Points',
                             'Wins', 'Draws', 'Losses', 'Goals For',
                             'Goals Against', 'Goal Difference'])
    return df

# %%
# Function Call

bundesliga_df = bundesliga_scrape()

bundesliga_df
# Out:
#     Rank                  Team Matches Points Wins Draws Losses Goals For  \
# 0      1     FC Bayern München      22     52   17     1      4        70
# 1      2     Borussia Dortmund      22     46   15     1      6        57
# 2      3   Bayer 04 Leverkusen      22     41   12     5      5        58
# 3      4            RB Leipzig      22     34   10     4      8        43
# 4      5        TSG Hoffenheim      22     34   10     4      8        43
# 5      6           SC Freiburg      22     34    9     7      6        34
# 6      7    1. FC Union Berlin      22     34    9     7      6        29
# 7      8            1. FC Köln      22     32    8     8      6        34
# 8      9       1. FSV Mainz 05      22     31    9     4      9        31
# 9     10   Eintracht Frankfurt      22     31    8     7      7        33
# 10    11       VfL Bochum 1848      22     28    8     4     10        24
# 11    12         VfL Wolfsburg      22     27    8     3     11        23
# 12    13   Borussia M'gladbach      22     26    7     5     10        30
# 13    14         Hertha Berlin      22     23    6     5     11        24
# 14    15     Arminia Bielefeld      22     22    4    10      8        21
# 15    16           FC Augsburg      22     22    5     7     10        24
# 16    17         VfB Stuttgart      22     18    4     6     12        26
# 17    18  SpVgg Greuther Fürth      22     13    3     4     15        20
#
#    Goals Against Goal Difference
# 0             25              45
# 1             36              21
# 2             36              22
# 3             27              16
# 4             34               9
# 5             25               9
# 6             30              -1
# 7             37              -3
# 8             24               7
# 9             34              -1
# 10            32              -8
# 11            33             -10
# 12            40             -10
# 13            45             -21
# 14            29              -8
# 15            38             -14
# 16            42             -16
# 17            57             -37

# %%
# Today's date:

from datetime import date

date.today()
# Out:
# datetime.date(2022, 2, 15)

# %%
'bundesliga_table_' + str(date.today())
# Out:
# 'bundesliga_table_2022-02-15'

# %%
# Save to .csv:

bundesliga_df.to_csv('bundesliga_table_' + str(date.today()) + '.csv', index = False)
